# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('geophone-sensor-data.csv')
df
# Out:
#      timestamp         mean   top_3_mean   min   max   std_dev  median  \
# 0     01:51:43  2046.726000  2057.666667  2035  2060  3.452186  2047.0
# 1     01:51:46  2046.619333  2053.000000  2040  2053  3.580469  2047.0
# 2     01:51:50  2046.598000  2056.000000  2030  2059  3.592826  2047.0
# 3     01:51:53  2046.560000  2054.000000  2039  2055  3.414830  2047.0
# 4     01:51:56  2046.656667  2055.000000  2034  2057  3.356802  2048.0
# ...        ...          ...          ...   ...   ...       ...     ...
# 1795  21:17:01  2037.587333  2040.000000  2034  2040  1.564089  2038.0
# 1796  21:17:04  2037.606000  2041.333333  2033  2042  2.160578  2038.0
# 1797  21:17:07  2037.984000  2041.000000  2034  2041  1.686736  2038.0
# 1798  21:17:10  2037.482000  2041.000000  2033  2041  2.123286  2037.0
# 1799  21:17:13  2038.450000  2041.000000  2035  2041  1.623012  2039.0
#
#           q1      q3  skewness  dominant_freq        energy activity   name
# ...

# %%
df.head()
# Out:
#   timestamp         mean   top_3_mean   min   max   std_dev  median      q1  \
# 0  01:51:43  2046.726000  2057.666667  2035  2060  3.452186  2047.0  2043.0
# 1  01:51:46  2046.619333  2053.000000  2040  2053  3.580469  2047.0  2044.0
# 2  01:51:50  2046.598000  2056.000000  2030  2059  3.592826  2047.0  2044.0
# 3  01:51:53  2046.560000  2054.000000  2039  2055  3.414830  2047.0  2044.0
# 4  01:51:56  2046.656667  2055.000000  2034  2057  3.356802  2048.0  2044.0
#
#        q3  skewness  dominant_freq        energy activity   name
# 0  2049.0 -0.152574          601.0  1.988682e+09  walking  Yusuf
# 1  2050.0 -0.150615          300.0  1.988028e+09  walking  Yusuf
# 2  2049.0 -0.370125          300.0  1.987897e+09  walking  Yusuf
# 3  2049.0 -0.321296          300.0  1.987662e+09  walking  Yusuf
# 4  2049.0 -0.379134          300.0  1.988255e+09  walking  Yusuf

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      timestamp         mean   top_3_mean   min   max   std_dev  median  \
# 0     01:51:43  2046.726000  2057.666667  2035  2060  3.452186  2047.0
# 1     01:51:46  2046.619333  2053.000000  2040  2053  3.580469  2047.0
# 2     01:51:50  2046.598000  2056.000000  2030  2059  3.592826  2047.0
# 3     01:51:53  2046.560000  2054.000000  2039  2055  3.414830  2047.0
# 4     01:51:56  2046.656667  2055.000000  2034  2057  3.356802  2048.0
# ...        ...          ...          ...   ...   ...       ...     ...
# 1795  21:17:01  2037.587333  2040.000000  2034  2040  1.564089  2038.0
# 1796  21:17:04  2037.606000  2041.333333  2033  2042  2.160578  2038.0
# 1797  21:17:07  2037.984000  2041.000000  2034  2041  1.686736  2038.0
# 1798  21:17:10  2037.482000  2041.000000  2033  2041  2.123286  2037.0
# 1799  21:17:13  2038.450000  2041.000000  2035  2041  1.623012  2039.0
#
#           q1      q3  skewness  dominant_freq        energy activity   name
# ...

# %%
#checking for nulls
df.isnull().sum()
# Out:
# timestamp        0
# mean             0
# top_3_mean       0
# min              0
# max              0
# std_dev          0
# median           0
# q1               0
# q3               0
# skewness         0
# dominant_freq    0
# energy           0
# activity         0
# name             0
# dtype: int64

# %%
#finding relation between features using pairplot
plt.figure(figsize=(2,2))
sns.pairplot(df[['mean','timestamp','min','max']])
plt.title('Relation between features')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(df[['timestamp','mean','min','max']])
plt.title('count of features by year wise')
plt.xlabel('Years')
plt.plot()
# Out:
# []

# %%
#detection outliers
plt.figure(figsize=(5,7))
plt.boxplot(df[['mean','min','max','top_3_mean','dominant_freq','skewness']])
plt.show()

# %%
#removing outliers
q1=df['mean'].quantile(0.25)
q3=df['mean'].quantile(0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3-1.5*iqr
data=df[(df['mean']>=lower) &(df['mean']<=upper)]
print(data)
# Out:
#      timestamp         mean   top_3_mean   min   max   std_dev  median  \
# 480   21:03:40  2036.136000  2040.000000  2032  2040  2.218146  2036.0
# 501   21:04:44  2036.304667  2045.666667  2016  2049  2.468436  2036.0
# 504   21:04:53  2036.286000  2040.333333  2032  2041  2.328419  2036.0
# 506   21:04:59  2036.276667  2052.000000  2009  2055  2.458208  2037.0
# 507   21:05:02  2035.612667  2040.333333  2030  2041  2.512629  2035.0
# 508   21:05:05  2035.834667  2061.333333  1989  2067  3.018940  2036.0
# 509   21:05:08  2036.132667  2041.000000  2030  2041  2.648094  2036.0
# 510   21:05:11  2035.354667  2047.666667  2018  2050  2.428349  2036.0
# 511   21:05:14  2035.094000  2039.666667  2030  2040  2.607393  2034.0
# 512   21:05:17  2035.426000  2054.666667  2007  2058  3.037190  2035.0
# 513   21:05:20  2035.498667  2048.666667  2015  2050  2.480725  2036.0
# 514   21:05:23  2034.810667  2039.666667  2030  2040  2.695209  2034.0
# ...

# %%
plt.boxplot(data['mean'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d313b11b20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d313b12030>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d313b11880>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d313b12510>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d313b12750>],
#  'means': []}

# %%
q1=df['max'].quantile(0.25)
q3=df['max'].quantile(0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3-1.5*iqr
data=df[(df['max']>=lower) &(df['max']<=upper)]
print(data)
# Out:
# Empty DataFrame
# Columns: [timestamp, mean, top_3_mean, min, max, std_dev, median, q1, q3, skewness, dominant_freq, energy, activity, name]
# Index: []

# %%
plt.boxplot(data['max'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d313b85d30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d313b86210>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d313b3d250>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d313b86660>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d313b86900>],
#  'means': []}

# %%
q1=df['min'].quantile(0.25)
q3=df['min'].quantile(0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3-1.5*iqr
data=df[(df['min']>=lower) &(df['min']<=upper)]
print(data)
plt.boxplot(data['mean'])
# Out:
#      timestamp         mean   top_3_mean   min   max   std_dev  median  \
# 508   21:05:05  2035.834667  2061.333333  1989  2067  3.018940  2036.0
# 592   21:09:20  2037.646667  2057.000000  1997  2058  3.338336  2038.0
# 606   16:30:30  2048.744000  2082.666667  1997  2089  3.768262  2049.0
# 650   03:25:54  2040.150000  2066.333333  1999  2068  3.780586  2040.5
# 683   03:27:34  2041.014667  2064.000000  1992  2065  3.800147  2041.0
# 890   03:33:17  2039.166000  2064.000000  1999  2067  3.037287  2040.0
# 939   03:35:46  2039.597333  2080.000000  1999  2085  4.853644  2040.0
# 949   03:36:16  2039.428667  2076.666667  2000  2081  4.538382  2039.0
# 952   03:36:25  2039.125333  2079.666667  1997  2085  4.256637  2040.0
# 1110  20:55:44  2038.660667  2060.666667  1991  2064  2.932607  2038.0
# 1131  20:56:47  2043.484667  2090.666667  1990  2094  4.448119  2044.0
# 1135  20:56:59  2037.635333  2072.000000  1984  2076  3.778141  2038.0
# ...

# %%
q1=df['top_3_mean'].quantile(0.35)
q3=df['top_3_mean'].quantile(0.70)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3-1.5*iqr
data=df[(df['top_3_mean']>=lower) &(df['top_3_mean']<=upper)]
print(data)
plt.boxplot(data['top_3_mean'])
# Out:
#      timestamp         mean   top_3_mean   min   max   std_dev  median  \
# 480   21:03:40  2036.136000  2040.000000  2032  2040  2.218146  2036.0
# 487   21:04:02  2037.416667  2042.333333  2033  2043  2.504740  2037.0
# 490   21:04:11  2036.465333  2041.000000  2030  2041  2.565307  2036.0
# 497   21:04:32  2036.808000  2041.000000  2033  2041  2.109456  2037.0
# 500   21:04:41  2036.652667  2041.666667  2030  2042  2.158709  2037.0
# ...        ...          ...          ...   ...   ...       ...     ...
# 1795  21:17:01  2037.587333  2040.000000  2034  2040  1.564089  2038.0
# 1796  21:17:04  2037.606000  2041.333333  2033  2042  2.160578  2038.0
# 1797  21:17:07  2037.984000  2041.000000  2034  2041  1.686736  2038.0
# 1798  21:17:10  2037.482000  2041.000000  2033  2041  2.123286  2037.0
# 1799  21:17:13  2038.450000  2041.000000  2035  2041  1.623012  2039.0
#
#           q1      q3  skewness  dominant_freq        energy activity  name
# ...

# %%
df
# Out:
#      timestamp         mean   top_3_mean   min   max   std_dev  median  \
# 0     01:51:43  2046.726000  2057.666667  2035  2060  3.452186  2047.0
# 1     01:51:46  2046.619333  2053.000000  2040  2053  3.580469  2047.0
# 2     01:51:50  2046.598000  2056.000000  2030  2059  3.592826  2047.0
# 3     01:51:53  2046.560000  2054.000000  2039  2055  3.414830  2047.0
# 4     01:51:56  2046.656667  2055.000000  2034  2057  3.356802  2048.0
# ...        ...          ...          ...   ...   ...       ...     ...
# 1795  21:17:01  2037.587333  2040.000000  2034  2040  1.564089  2038.0
# 1796  21:17:04  2037.606000  2041.333333  2033  2042  2.160578  2038.0
# 1797  21:17:07  2037.984000  2041.000000  2034  2041  1.686736  2038.0
# 1798  21:17:10  2037.482000  2041.000000  2033  2041  2.123286  2037.0
# 1799  21:17:13  2038.450000  2041.000000  2035  2041  1.623012  2039.0
#
#           q1      q3  skewness  dominant_freq        energy activity   name
# ...

# %%
data
# Out:
#      timestamp         mean   top_3_mean   min   max   std_dev  median  \
# 480   21:03:40  2036.136000  2040.000000  2032  2040  2.218146  2036.0
# 487   21:04:02  2037.416667  2042.333333  2033  2043  2.504740  2037.0
# 490   21:04:11  2036.465333  2041.000000  2030  2041  2.565307  2036.0
# 497   21:04:32  2036.808000  2041.000000  2033  2041  2.109456  2037.0
# 500   21:04:41  2036.652667  2041.666667  2030  2042  2.158709  2037.0
# ...        ...          ...          ...   ...   ...       ...     ...
# 1795  21:17:01  2037.587333  2040.000000  2034  2040  1.564089  2038.0
# 1796  21:17:04  2037.606000  2041.333333  2033  2042  2.160578  2038.0
# 1797  21:17:07  2037.984000  2041.000000  2034  2041  1.686736  2038.0
# 1798  21:17:10  2037.482000  2041.000000  2033  2041  2.123286  2037.0
# 1799  21:17:13  2038.450000  2041.000000  2035  2041  1.623012  2039.0
#
#           q1      q3  skewness  dominant_freq        energy activity  name
# ...

# %%
df.shape
# Out:
# (1800, 14)

# %%
data.shape
# Out:
# (152, 14)

# %%
df
# Out:
#      timestamp         mean   top_3_mean   min   max   std_dev  median  \
# 0     01:51:43  2046.726000  2057.666667  2035  2060  3.452186  2047.0
# 1     01:51:46  2046.619333  2053.000000  2040  2053  3.580469  2047.0
# 2     01:51:50  2046.598000  2056.000000  2030  2059  3.592826  2047.0
# 3     01:51:53  2046.560000  2054.000000  2039  2055  3.414830  2047.0
# 4     01:51:56  2046.656667  2055.000000  2034  2057  3.356802  2048.0
# ...        ...          ...          ...   ...   ...       ...     ...
# 1795  21:17:01  2037.587333  2040.000000  2034  2040  1.564089  2038.0
# 1796  21:17:04  2037.606000  2041.333333  2033  2042  2.160578  2038.0
# 1797  21:17:07  2037.984000  2041.000000  2034  2041  1.686736  2038.0
# 1798  21:17:10  2037.482000  2041.000000  2033  2041  2.123286  2037.0
# 1799  21:17:13  2038.450000  2041.000000  2035  2041  1.623012  2039.0
#
#           q1      q3  skewness  dominant_freq        energy activity   name
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['timestamp'] = pd.to_numeric(df['timestamp'], errors='coerce')  
#df['Label'] = pd.to_numeric(df['Label'], errors='coerce')
df
# Out:
# C:\Users\shiva matam\AppData\Local\Temp\ipykernel_12344\2430596885.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['timestamp'] = pd.to_numeric(df['timestamp'], errors='coerce')
#      timestamp         mean   top_3_mean   min   max   std_dev  median  \
# 0            0  2046.726000  2057.666667  2035  2060  3.452186  2047.0
# 1            1  2046.619333  2053.000000  2040  2053  3.580469  2047.0
# 2            2  2046.598000  2056.000000  2030  2059  3.592826  2047.0
# 3            3  2046.560000  2054.000000  2039  2055  3.414830  2047.0
# 4            4  2046.656667  2055.000000  2034  2057  3.356802  2048.0
# ..         ...          ...          ...   ...   ...       ...     ...
# ...

# %%
# Out:
# 152

# %%
if len(df) != len(data):
    min_samples = min(len(df), len(data))
    df = df[:min_samples]
    data= data[:min_samples]

# %%
X = df[['mean', 'top_3_mean', 'min', 'max', 'std_dev', 'median', 
                'q1', 'q3', 'skewness', 'dominant_freq', 'energy',
                'timestamp']] # Features (input variables)
y = df['activity']  # Target variable

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
X_train,X_test,y_train,y_test=train_test_split(df,data,test_size=0.2,random_state=42)

# %%
#predicting using linear regression
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %% [raw]
# X_train=lr.fit_transform(X_train)
# X_test=lr.fit(X_test)

# %%
X_train.shape
# Out:
# (121, 14)

# %%
X_test.shape
# Out:
# (31, 14)

# %%
y_pred=lr.fit(X_train,y_train)
y_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 y_pred=lr.fit(X_train,y_train)
#       2 y_pred
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
#     607 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 609 X, y = self._validate_data(
#     610     X,
#     611     y,
# ...

# %%
def apply_ml_models(X_train, X_test, y_train, y_test):
    model = {
        'Linear Regression': LogisticRegression(),
    }
for name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        ACC = accuracy_score(y_test, y_pred)
        
        
        results[name] = {'ACC': ACC}
    
return results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[498], line 5
#       1 def apply_ml_models(X_train, X_test, y_train, y_test):
#       2     models = {
#       3         'Linear Regression': LogisticRegression(),
#       4     }
# ----> 5 for name, model in models.items():
#       6         model.fit(X_train, y_train)
#       7         y_pred = model.predict(X_test)
#
# NameError: name 'models' is not defined

# %%
y_pred=lr.fit(X_train,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[399], line 1
# ----> 1 y_pred=lr.fit(X_train,y_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
#     607 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 609 X, y = self._validate_data(
#     610     X,
#     611     y,
#     612     accept_sparse=accept_sparse,
# ...
